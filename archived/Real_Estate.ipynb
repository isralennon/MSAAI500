# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as stats

# %%
#RealEstate = pd.read_csv('https://archive.ics.uci.edu/static/public/477/data.csv', sep=',')
RealEstate = pd.read_csv('C:\\Users\\isral\\OneDrive\\Documentos\\Escuela Israel\\AAI-500 - Probability and Statistics\\Real estate valuation data set-Clean.csv', sep=',')

RealEstate.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
RealEstate.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
RealEstate['Y house price of unit area'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
RealEstate.isnull().describe()
# Out:
#            No X1 transaction date X2 house age  \
# count     414                 414          414
# unique      1                   1            1
# top     False               False        False
# freq      414                 414          414
#
#        X3 distance to the nearest MRT station X4 number of convenience stores  \
# count                                     414                             414
# unique                                      1                               1
# top                                     False                           False
# freq                                      414                             414
#
#        X5 latitude X6 longitude Y house price of unit area
# count          414          414                        414
# unique           1            1                          1
# top          False        False                      False
# freq           414          414                        414

# %%
import wolta
wolta.data_tools.col_types(RealEstate)
# Out:
# ['int64',
#  'float64',
#  'float64',
#  'float64',
#  'int64',
#  'float64',
#  'float64',
#  'float64']

# %%
# pearson correlation
RealEstate.corr(method='pearson')
plt.figure(figsize=(12,10))
cor = RealEstate.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Accent)
plt.show()
